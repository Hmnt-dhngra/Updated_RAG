# %% [markdown]
# # 📚 Notebook 01: Introduction and Fundamentals
#
# **LangChain 1.0.5+ | Mixed Level Class**
#
# ---
#
# ## 🎯 Learning Objectives
#
# By the end of this notebook, you will understand:
# 1. What LangChain is and why it's useful
# 2. LangChain's modular architecture
# 3. Core concepts: Documents, Chains, and LCEL
# 4. How to set up your development environment
# 5. The difference between LangChain and traditional ML pipelines
#
# ---
#
# ## 📖 Table of Contents
#
# 1. [What is LangChain?](#what-is-langchain)
# 2. [LangChain Architecture](#architecture)
# 3. [Environment Setup](#setup)
# 4. [Core Concepts](#core-concepts)
# 5. [Quick Start Example](#quick-start)
# 6. [LangChain vs Traditional Pipelines](#comparison)
# 7. [Summary & Next Steps](#summary)
#
# ---

# %% [markdown]
# <a id="what-is-langchain"></a>
# ## 1. What is LangChain? 🤔
#
# ### 🔰 BEGINNER SECTION
#
# **LangChain** is an open-source framework that makes it easy to build applications powered by Large Language Models (LLMs) like GPT-4, Claude, or Llama.
#
# ### Why LangChain?
#
# Imagine you want to build a chatbot that can:
# - Answer questions about your company's PDF documents
# - Search through your database
# - Remember previous conversations
# - Call external APIs
#
# Without LangChain, you'd need to:
# 1. ✍️ Write code to load and parse PDFs
# 2. ✍️ Convert text to embeddings
# 3. ✍️ Store embeddings in a vector database
# 4. ✍️ Implement semantic search
# 5. ✍️ Format prompts for the LLM
# 6. ✍️ Handle LLM API calls
# 7. ✍️ Manage conversation memory
#
# **With LangChain:**
# - ✅ All these components are pre-built and ready to use
# - ✅ You just connect them like LEGO blocks
# - ✅ Focus on your application logic, not infrastructure
#
# ### 🎓 INTERMEDIATE NOTE
#
# LangChain provides:
# - **Abstractions**: Unified interfaces for different LLMs, vector stores, and tools
# - **Chains**: Composable workflows using LCEL (LangChain Expression Language)
# - **Agents**: Autonomous systems that can use tools and make decisions
# - **Memory**: Conversation history and context management
# - **Callbacks**: Monitoring, logging, and debugging hooks

# %% [markdown]
# <a id="architecture"></a>
# ## 2. LangChain Architecture 🏗️
#
# ### 🔰 BEGINNER: Visual Architecture
#
# ```
# ┌─────────────────────────────────────────────────────────┐
# │                    YOUR APPLICATION                     │
# └─────────────────────────────────────────────────────────┘
#                            ↓
# ┌─────────────────────────────────────────────────────────┐
# │                  LANGCHAIN FRAMEWORK                    │
# │  ┌──────────┐  ┌──────────┐  ┌──────────┐  ┌─────────┐  │
# │  │ Document │  │   Text   │  │ Embeddings│  │ Vector  │ │
# │  │ Loaders  │→ │ Splitters│→ │  Models   │→ │ Stores  │ │
# │  └──────────┘  └──────────┘  └──────────┘  └─────────┘│
# │                                                         │
# │  ┌──────────┐  ┌──────────┐  ┌──────────┐               │
# │  │Retrievers│  │ Prompts  │  │   LLMs   │               │
# │  └──────────┘  └──────────┘  └──────────┘               │
# │                                                         │
# │  ┌──────────────────────────────────────────────────┐   │
# │  │         LCEL (LangChain Expression Language)     │   │
# │  │         Connects everything with | operator      │   │
# │  └──────────────────────────────────────────────────┘   │
# └─────────────────────────────────────────────────────────┘
#                            ↓
# ┌─────────────────────────────────────────────────────────┐
# │             EXTERNAL SERVICES & DATA                    │
# │  • OpenAI/Anthropic APIs  • Vector Databases            │
# │  • PDF Files              • Websites                    │
# │  • Databases              • APIs                        │
# └─────────────────────────────────────────────────────────┘
# ```
#
# ### 🎓 INTERMEDIATE: Package Structure (LangChain 1.0+)
#
# LangChain is organized into several packages:
#
# | Package | Purpose | Example Imports |
# |---------|---------|------------------|
# | **langchain-core** | Core abstractions, base classes | `from langchain_core.documents import Document` |
# | **langchain-community** | Community integrations (loaders, vector stores) | `from langchain_community.document_loaders import PyPDFLoader` |
# | **langchain-openai** | OpenAI-specific integrations | `from langchain_openai import ChatOpenAI, OpenAIEmbeddings` |
# | **langchain-text-splitters** | Text splitting utilities | `from langchain_text_splitters import RecursiveCharacterTextSplitter` |
#
# **Why this matters:** In LangChain 1.0+, you import from specific packages instead of `langchain` directly. This reduces dependencies and improves modularity.

# %% [markdown]
# <a id="setup"></a>
# ## 3. Environment Setup 🛠️
#
# ### 🔰 BEGINNER: Step-by-Step Setup
#
# Let's verify your environment is ready!

# %%
# Step 1: Check Python version (should be 3.9+)
import sys
print(f"Python version: {sys.version}")

# Check if Python is 3.9 or higher
if sys.version_info >= (3, 9):
    print("✅ Python version is compatible")
else:
    print("❌ Please upgrade to Python 3.9 or higher")
# Out:
# Python version: 3.13.5 (main, Jul 23 2025, 00:30:06) [MSC v.1944 64 bit (AMD64)]
# ✅ Python version is compatible

# %%
# Step 2: Import LangChain and check version
import langchain
from langchain_core import __version__ as core_version

print(f"LangChain version: {langchain.__version__}")
print(f"LangChain Core version: {core_version}")

# We're using LangChain 1.0.5+ for this course
if langchain.__version__ >= "1.0":
    print("✅ LangChain 1.0+ detected")
else:
    print("❌ Please upgrade: pip install --upgrade langchain")
# Out:
# LangChain version: 1.2.12
# LangChain Core version: 1.2.19
# ✅ LangChain 1.0+ detected

# %%
# Step 3: Load environment variables (API keys)
from dotenv import load_dotenv
import os

# Load .env file
load_dotenv()

# Check if OpenAI API key is set
# NOTE: We don't print the actual key for security!
if os.getenv("OPENAI_API_KEY"):
    print("✅ OPENAI_API_KEY found")
else:
    print("❌ OPENAI_API_KEY not found")
    print("   Create a .env file with: OPENAI_API_KEY=your-key-here")

# Check for Google API key (optional, for Google Gemini)
if os.getenv("GOOGLE_API_KEY"):
    print("✅ GOOGLE_API_KEY found")
else:
    print("⚠️  GOOGLE_API_KEY not found (optional for this notebook)")
# Out:
# ✅ OPENAI_API_KEY found
# ⚠️  GOOGLE_API_KEY not found (optional for this notebook)

# %% [markdown]
# ### 📝 Setting Up Your .env File
#
# If you don't have a `.env` file, create one in the project root:
#
# ```bash
# # .env file
# OPENAI_API_KEY=sk-proj-your-key-here
# GOOGLE_API_KEY=your-google-key-here
# ```
#
# **⚠️ SECURITY WARNING:**
# - Never commit `.env` files to Git
# - Add `.env` to your `.gitignore` file
# - Never hardcode API keys in your code

# %% [markdown]
# <a id="core-concepts"></a>
# ## 4. Core Concepts 📚
#
# ### 4.1 Documents 📄
#
# ### 🔰 BEGINNER
#
# A **Document** is LangChain's way of representing a piece of text with metadata.
#
# Think of it like a note card:
# - **Front (page_content):** The actual text
# - **Back (metadata):** Information about the text (source, page number, date, etc.)

# %%
# Creating a Document manually
from langchain_core.documents import Document

# Create a simple document
doc = Document(
    page_content="LangChain makes building LLM applications easy!",
    metadata={
        "source": "introduction.txt",
        "author": "LangChain Team",
        "date": "2025-01-15"
    }
)

# Access the content
print("Content:")
print(doc.page_content)
print("\nMetadata:")
print(doc.metadata)
print(f"\nSource: {doc.metadata['source']}")
# Out:
# Content:
# LangChain makes building LLM applications easy!
#
# Metadata:
# {'source': 'introduction.txt', 'author': 'LangChain Team', 'date': '2025-01-15'}
#
# Source: introduction.txt

# %% [markdown]
# ### 🎓 INTERMEDIATE: Why Metadata Matters
#
# Metadata is crucial for:
# 1. **Citation**: Showing users where information came from
# 2. **Filtering**: Only search documents from specific sources
# 3. **Debugging**: Tracking which documents are being retrieved
# 4. **Analytics**: Understanding which sources are most useful

# %%
# Creating multiple documents (like a mini knowledge base)
documents = [
    Document(
        page_content="Python is a high-level programming language.",
        metadata={"category": "programming", "difficulty": "beginner"}
    ),
    Document(
        page_content="Machine learning is a subset of artificial intelligence.",
        metadata={"category": "AI", "difficulty": "intermediate"}
    ),
    Document(
        page_content="RAG combines retrieval and generation for better LLM outputs.",
        metadata={"category": "AI", "difficulty": "advanced"}
    )
]

# Print all documents
for i, doc in enumerate(documents, 1):
    print(f"\n📄 Document {i}:")
    print(f"   Content: {doc.page_content}")
    print(f"   Category: {doc.metadata['category']}")
    print(f"   Difficulty: {doc.metadata['difficulty']}")
# Out:
# 📄 Document 1:
#    Content: Python is a high-level programming language.
#    Category: programming
#    Difficulty: beginner
#
# 📄 Document 2:
#    Content: Machine learning is a subset of artificial intelligence.
#    Category: AI
#    Difficulty: intermediate
#
# 📄 Document 3:
#    Content: RAG combines retrieval and generation for better LLM outputs.
#    Category: AI
#    Difficulty: advanced

# %% [markdown]
# ### 4.2 LCEL (LangChain Expression Language) 🔗
#
# ### 🔰 BEGINNER
#
# **LCEL** is a way to connect different components using the pipe operator `|`.
#
# Think of it like a factory assembly line:
# ```
# Input → Component 1 → Component 2 → Component 3 → Output
# ```
#
# ### Before LCEL (Old Way - Messy!):
# ```python
# output = component3(component2(component1(input)))
# ```
#
# ### With LCEL (New Way - Clean!):
# ```python
# chain = component1 | component2 | component3
# output = chain.invoke(input)
# ```

# %% [markdown]
# ### 🎓 INTERMEDIATE: LCEL Deep Dive
#
# LCEL provides:
# - **Streaming**: Stream outputs as they're generated
# - **Batch Processing**: Process multiple inputs efficiently
# - **Async Support**: Non-blocking operations
# - **Debugging**: Better error messages and logging
# - **Type Safety**: Better IDE autocomplete
#
# **Key Methods:**
# - `.invoke(input)`: Process single input
# - `.batch([input1, input2])`: Process multiple inputs
# - `.stream(input)`: Stream output tokens
# - `.ainvoke(input)`: Async version of invoke

# %%
# Simple LCEL Example: String Transformation Chain
from langchain_core.runnables import RunnableLambda

# Create simple transformation functions
def uppercase(text: str) -> str:
    """Convert text to uppercase"""
    print(f"  Step 1: uppercase → {text.upper()}")
    return text.upper()

def add_prefix(text: str) -> str:
    """Add a prefix to text"""
    result = f"RESULT: {text}"
    print(f"  Step 2: add_prefix → {result}")
    return result

def add_emoji(text: str) -> str:
    """Add emoji to text"""
    result = f"✅ {text}"
    print(f"  Step 3: add_emoji → {result}")
    return result

# Create runnables (components that can be chained)
uppercase_runnable = RunnableLambda(uppercase)
prefix_runnable = RunnableLambda(add_prefix)
emoji_runnable = RunnableLambda(add_emoji)

# Build the chain using LCEL
chain = uppercase_runnable | prefix_runnable | emoji_runnable

# Execute the chain
print("Input: 'hello langchain'")
print("\nProcessing:")
result = chain.invoke("hello langchain")
print(f"\nFinal Output: {result}")
# Out:
# Input: 'hello langchain'
#
# Processing:
#   Step 1: uppercase → HELLO LANGCHAIN
#   Step 2: add_prefix → RESULT: HELLO LANGCHAIN
#   Step 3: add_emoji → ✅ RESULT: HELLO LANGCHAIN
#
# Final Output: ✅ RESULT: HELLO LANGCHAIN

# %% [markdown]
# ### 4.3 Chains 🔗
#
# ### 🔰 BEGINNER
#
# A **Chain** is a sequence of operations. Common chain types:
#
# 1. **Simple Chain**: Input → Process → Output
# 2. **RAG Chain**: Query → Retrieve → Generate → Answer
# 3. **Multi-step Chain**: Input → Step 1 → Step 2 → Step 3 → Output
#
# We'll build complex chains in later notebooks!

# %% [markdown]
# <a id="quick-start"></a>
# ## 5. Quick Start Example 🚀
#
# ### 🔰 BEGINNER: Your First LLM Call
#
# Let's make our first call to an LLM using LangChain!

# %%
# Import ChatOpenAI (the LLM interface)
from langchain_openai import ChatOpenAI

# Initialize the LLM
# model: Which GPT model to use
# temperature: 0 = deterministic, 1 = creative
llm = ChatOpenAI(
    model="gpt-5-nano",  # Cheaper, faster model for learning
    temperature=0  # Deterministic outputs for learning
)

# Make a simple call
response = llm.invoke("What is LangChain in two sentences?")

# Print the response
print("Question: What is LangChain in one sentence?")
print(f"\nAnswer: {response.content}")
# Out:
# Question: What is LangChain in one sentence?
#
# Answer: LangChain is a framework for building applications powered by large language models (LLMs). It provides modular components—prompts, chains, agents, memory, and tools—and integrations with data sources and services to orchestrate LLM reasoning and actions.

# %% [markdown]
# ### FOR GEMINI

# %%
# !uv pip install -U langchain-google-genai

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

# %%
llm = ChatGoogleGenerativeAI(
model="gemini-2.5-flash",  # Example Gemini model
temperature=0  # Deterministic outputs for learning
)

# Make a simple call
response = llm.invoke("What is LangChain in one sentence?")

# Print the response
print("Question: What is LangChain in one sentence?")
print(f"\nAnswer: {response.content}")

# %% [markdown]
# ### 🎓 INTERMEDIATE: Understanding the Response Object

# %%
# The response is an AIMessage object with metadata
print("Response Type:", type(response))
print("\nContent:", response.content)
print("\nResponse Metadata:")
print(response.response_metadata)

# Access specific metadata
if 'token_usage' in response.response_metadata:
    usage = response.response_metadata['token_usage']
    print(f"\nTokens Used:")
    print(f"  Prompt: {usage.get('prompt_tokens', 'N/A')}")
    print(f"  Completion: {usage.get('completion_tokens', 'N/A')}")
    print(f"  Total: {usage.get('total_tokens', 'N/A')}")
# Out:
# Response Type: <class 'langchain_core.messages.ai.AIMessage'>
#
# Content: LangChain is a framework for building applications powered by large language models (LLMs). It provides modular components—prompts, chains, agents, memory, and tools—and integrations with data sources and services to orchestrate LLM reasoning and actions.
#
# Response Metadata:
# {'token_usage': {'completion_tokens': 634, 'prompt_tokens': 14, 'total_tokens': 648, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 576, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DOIlHyZiuT5y0kAaiKqvw174FdUNA', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}
#
# Tokens Used:
#   Prompt: 14
#   Completion: 634
#   Total: 648

# %% [markdown]
# ### 🔰 BEGINNER: Using Prompts
#
# Instead of plain strings, use **prompt templates** for better control:

# %%
from langchain_core.prompts import ChatPromptTemplate


# Create a prompt template
# {topic} is a variable we'll fill in later
prompt = ChatPromptTemplate.from_template(
    "Explain {topic} in simple terms suitable for beginners."
)

# View the prompt structure
print("Prompt Template:")
print(prompt.messages[0].prompt.template)
# Out:
# Prompt Template:
# Explain {topic} in simple terms suitable for beginners.

# %%
# Build a chain: Prompt → LLM
from langchain_core.output_parsers import StrOutputParser

# Components:
# 1. prompt: Formats the input
# 2. llm: Generates the response
# 3. StrOutputParser: Extracts just the text from the response

chain = prompt | llm | StrOutputParser()

# Use the chain with different topics
topics = ["machine learning", "embeddings", "vector databases"]

for topic in topics:
    print(f"\n{'='*60}")
    print(f"Topic: {topic.upper()}")
    print('='*60)
    
    # Invoke the chain
    explanation = chain.invoke({"topic": topic})
    print(explanation)
# Out:
# ============================================================
# Topic: MACHINE LEARNING
# ============================================================
# Machine learning is a way for computers to learn from examples and make guesses or decisions without being told exactly what to do every time.
#
# Simple idea you can relate to:
# - You show someone lots of pictures labeled “cat” or “dog.”
# - They notice patterns (like whiskers, ears, tail shape) and start guessing whether a new picture is a cat or a dog.
# - If they’re wrong, you correct them and they adjust their guess next time.
#
# What’s happening in ML (in plain language)
# - Data: a bunch of examples you give the computer (like labeled pictures, emails, or movie ratings).
# - Features: the bits of information about each example (color, size, words in an email, etc.).
# - Model: the “rule book” the computer learns to make a guess from the features.
# - Training: the computer looks at the data and adjusts the model so its guesses match the labels as often as possible.
# - Prediction: after training, the model can guess the label for new, unseen examples.
# - Evaluation: you test the model on new data to see how well it does.
#
# Types of learning (very simple)
# - Supervised learning: you give examples with the right answers (labeled data). Examples: spam/not-spam email, house prices from features like size and location.
# - Unsupervised learning: you don’t give the right answers. The model discovers patterns on its own. Examples: grouping customers into similar types, finding topics in a set of documents.
# - Reinforcement learning: the model learns by trying things and getting feedback (rewards or penalties). Examples: teaching a robot to walk, a game-playing agent learning strategies.
#
# A tiny, concrete example
# - Spam filter:
#   - Data: lots of emails labeled “spam” or “not spam.”
#   - Features: presence of certain words, sender, length.
#   - Model: a rule that says an email is spam if those features match the spam examples.
#   - Training: adjust the rule so it correctly labels many emails in your data.
#   - Prediction: future emails get labeled as spam or not spam.
#   - Evaluation: check how many mistakes it makes on new emails and improve if needed.
#
# Key ideas to remember
# - More and better data usually helps, but biased or poor data can lead to bad results.
# - Models can overfit: they memorize the training examples but don’t do well on new ones.
# - It’s a balance between simplicity (fast, easy to understand) and power (fits the data well).
#
# Common terms (quick gloss)
# - Model: the learned rule or algorithm that makes predictions.
# - Features: the inputs used to make a prediction.
# - Label: the correct answer in your training data.
# - Training: the process of learning from data.
# - Prediction: the model’s guess for new data.
# - Accuracy: how often the predictions are correct.
#
# If you want, I can tailor this to a specific topic you’re curious about (like weather forecasts, music recommendations, or image labeling) or give a super-simple hands-on mini exercise you can try.
#
# ============================================================
# Topic: EMBEDDINGS
# ============================================================
# Embeddings are a way to represent things (like words, sentences, or pictures) as numbers so computers can understand and compare them.
#
# Simple way to think about it:
# - Imagine every word getting a coordinate on a map. The map is not 2D like a paper map; it’s a space with many dimensions (often hundreds).
# - Words that mean similar things end up close to each other on this map. Words with different meanings end up far apart.
#
# Why this is useful:
# - Computers can measure how similar two words are by looking at the distance between their coordinates.
# - They can feed these numbers into machine learning models instead of raw text, which makes learning patterns easier.
#
# How embeddings are made (in simple terms):
# - A model is trained on lots of data (text, images, etc.).
# - The model learns to place items into this numeric space so that items appearing in similar contexts end up near each other.
# - The result is a vector (a list of numbers) for each item.
#
# Common types you might hear about:
# - Word embeddings: for individual words (e.g., “cat” and “dog” have similar vectors).
# - Sentence or document embeddings: for phrases, sentences, or entire documents.
# - Image embeddings: for pictures (how a photo relates to other photos).
#
# How we use them:
# - In a model, you feed the embedding vectors instead of raw words.
# - You can measure similarity with simple tools like cosine similarity.
# - Embeddings can capture relationships, like analogies (in many word embeddings, “king” is to “queen” as “man” is to “woman”).
#
# Important caveats:
# - Embeddings reflect the data they were trained on, including biases.
# - They’re high-dimensional and can be hard to interpret directly.
# - They need good data and care in how they’re used, especially for sensitive tasks.
#
# If you’d like, I can give a tiny, concrete example (even with 2D, toy vectors) to show how similar words end up close together, or explain how real word embeddings are trained (like Word2Vec or GloVe) in plain terms. What would you like to dive into?
#
# ============================================================
# Topic: VECTOR DATABASES
# ============================================================
# Here’s a beginner-friendly explanation of vector databases.
#
# What is a vector and what is an embedding?
# - A vector is just a list of numbers that represents something in a way a computer can compare quickly. For example, a short list like [0.2, 0.8, -0.5] can represent a word, a sentence, an image, or a product description.
# - An embedding is a special kind of vector created by a machine learning model. It captures the meaning or features of the data (text, images, sounds, etc.) so similar things end up with similar vectors.
#
# What is a vector database, and what problem does it solve?
# - A vector database stores lots of those vectors and lets you find items that are “close” to a given vector. It’s built for fast similarity search at scale.
# - The typical question you ask a vector database is: “Which items have vectors that are most similar to this query vector?”
#
# How it works, in simple terms
# - Step 1: Convert data to vectors (embeddings) using a model. For text, you might turn a product description or a question into a vector.
# - Step 2: Store those vectors (and usually some extra data like IDs or the original text) in the vector database.
# - Step 3: When you have a new query, convert it to a vector and ask the database to find the nearest vectors.
# - Step 4: The database returns the closest items, often ranked by similarity.
#
# Key ideas and terms
# - Embedding: the vector representation of data.
# - Distance or similarity: how close two vectors are. Common measures are cosine similarity (how aligned the directions are) or dot product/Euclidean distance.
# - Approximate nearest neighbors (ANN): a practical way to find near matches quickly, trading a tiny bit of accuracy for big speed gains.
# - Indexing: the database builds data structures to speed up searches, much like an index in a book but for vectors.
# - Hybrid search: combining vector similarity with traditional text filters or metadata (e.g., “show items similar to this but in category X”).
#
# Common use cases
# - Text: find documents or answers that are semantically similar to a query.
# - Images: find visually similar images.
# - Products: recommend items similar to what a user is viewing.
# - Documents or code: locate passages or snippets similar to a query.
# - Personalization: match users with items that have similar meanings or contexts.
#
# How vector databases differ from traditional databases
# - Traditional databases store exact values and support exact text or numeric queries. They aren’t optimized for finding “similar meaning.”
# - Vector databases store high-dimensional vectors and are optimized for similarity search. They’re great for semi-structured, ML-driven tasks like finding semantically related items.
# - Many projects use both: a hybrid approach where you filter by metadata with a traditional DB and then use vector search for semantic matching.
#
# What you typically do to use one
# - Choose a model to generate embeddings (e.g., a sentence transformer for text).
# - Convert your data into embeddings and store them in the vector database, along with IDs and any relevant metadata.
# - When a user or system provides a query, generate the query embedding, ask the vector DB for the top-K nearest neighbors, and then fetch the full data for those results if needed.
# - Optionally apply filters or metadata constraints to narrow results.
#
# Common options you might hear about
# - Popular vector databases: Pinecone, Milvus, Weaviate, Qdrant, Vespa.
# - Popular indexing techniques (briefly): HNSW (efficient approximate nearest neighbor search), IVF, PQ (compression methods). These help databases find similar items fast even with millions of vectors.
#
# A tiny toy example
# - You have 5 product descriptions. You turn each into a vector and store them with their product IDs.
# - A user searches for “cotton t-shirt.” You turn that query into a vector and ask the DB for the closest 3 product vectors.
# - The DB returns the 3 products whose embeddings are most similar to the query, which you then present to the user.
#
# Pros and cons to keep in mind
# - Pros: Enables powerful semantic search and recommendations; scales to large datasets; can be used with various data types (text, images, audio).
# - Cons: Quality depends on the embedding model; results are approximate unless you use exact search (which can be slower); requires more compute for embedding generation and indexing; handling updates can be more complex than in some traditional DB setups.
#
# If you’d like, I can give a simple, concrete example with a tiny dataset and show what the steps look like end-to-end (including sample embeddings and how you’d query it). Or tell me your use case (e.g., document search, product recommendations, image similarity) and I can tailor the explanation.

# %% [markdown]
# ### 🎓 INTERMEDIATE: Batch Processing
#
# Process multiple inputs efficiently using `.batch()`:

# %%
# Batch process multiple topics at once
topics_batch = [
    {"topic": "RAG"},
    {"topic": "LCEL"},
    {"topic": "LangChain agents"}
]

# Batch processing is more efficient than calling invoke() multiple times
results = chain.batch(topics_batch)

# Print results
for i, (input_dict, result) in enumerate(zip(topics_batch, results), 1):
    print(f"\n{i}. {input_dict['topic'].upper()}:")
    print(f"   {result[:100]}...")  # Print first 100 chars

# %% [markdown]
# <a id="comparison"></a>
# ## 6. LangChain vs Traditional ML Pipelines 🆚
#
# ### 🔰 BEGINNER: Key Differences
#
# | Aspect | Traditional ML | LangChain |
# |--------|---------------|------------|
# | **Setup** | Complex, manual | Pre-built components |
# | **Integration** | Write custom code | Use existing integrations |
# | **Composability** | Difficult to chain | Easy with LCEL |
# | **Debugging** | Manual logging | Built-in callbacks |
# | **Prototyping** | Slow | Very fast |
# | **Code Reuse** | Limited | High |
#
# ### Example: Building a Q&A System
#
# #### Without LangChain (50+ lines):
# ```python
# import openai
# import PyPDF2
# import faiss
# import numpy as np
#
# # 1. Load PDF manually
# def load_pdf(file_path):
#     reader = PyPDF2.PdfReader(file_path)
#     text = ""
#     for page in reader.pages:
#         text += page.extract_text()
#     return text
#
# # 2. Split text manually
# def split_text(text, chunk_size=1000):
#     chunks = []
#     for i in range(0, len(text), chunk_size):
#         chunks.append(text[i:i+chunk_size])
#     return chunks
#
# # 3. Create embeddings manually
# def create_embeddings(chunks):
#     embeddings = []
#     for chunk in chunks:
#         response = openai.Embedding.create(
#             input=chunk,
#             model="text-embedding-ada-002"
#         )
#         embeddings.append(response['data'][0]['embedding'])
#     return np.array(embeddings)
#
# # 4. Create vector store manually
# def create_vector_store(embeddings):
#     dimension = embeddings.shape[1]
#     index = faiss.IndexFlatL2(dimension)
#     index.add(embeddings)
#     return index
#
# # 5. Search manually
# def search(query, index, chunks):
#     query_embedding = openai.Embedding.create(
#         input=query,
#         model="text-embedding-ada-002"
#     )['data'][0]['embedding']
#
#     distances, indices = index.search(
#         np.array([query_embedding]), k=3
#     )
#     return [chunks[i] for i in indices[0]]
#
# # 6. Generate answer manually
# def generate_answer(query, context):
#     prompt = f"Context: {context}\n\nQuestion: {query}\n\nAnswer:"
#     response = openai.ChatCompletion.create(
#         model="gpt-3.5-turbo",
#         messages=[{"role": "user", "content": prompt}]
#     )
#     return response['choices'][0]['message']['content']
#
# # Use it:
# text = load_pdf("document.pdf")
# chunks = split_text(text)
# embeddings = create_embeddings(chunks)
# index = create_vector_store(embeddings)
# relevant_chunks = search("What is RAG?", index, chunks)
# answer = generate_answer("What is RAG?", " ".join(relevant_chunks))
# ```
#
# #### With LangChain (10 lines!):
# ```python
# from langchain_community.document_loaders import PyPDFLoader
# from langchain_text_splitters import RecursiveCharacterTextSplitter
# from langchain_openai import OpenAIEmbeddings, ChatOpenAI
# from langchain_community.vectorstores import FAISS
# from langchain_core.prompts import ChatPromptTemplate
# from langchain_core.output_parsers import StrOutputParser
# from langchain_core.runnables import RunnablePassthrough
#
# # Load, split, embed, and store
# docs = PyPDFLoader("document.pdf").load()
# chunks = RecursiveCharacterTextSplitter(chunk_size=1000).split_documents(docs)
# vectorstore = FAISS.from_documents(chunks, OpenAIEmbeddings())
# retriever = vectorstore.as_retriever()
#
# # Build RAG chain
# prompt = ChatPromptTemplate.from_template(
#     "Context: {context}\n\nQuestion: {question}\n\nAnswer:"
# )
# chain = (
#     {"context": retriever, "question": RunnablePassthrough()}
#     | prompt | ChatOpenAI() | StrOutputParser()
# )
#
# # Use it:
# answer = chain.invoke("What is RAG?")
# ```
#
# **50+ lines → 10 lines!** 🎉

# %% [markdown]
# <a id="summary"></a>
# ## 7. Summary & Next Steps 📝
#
# ### 🎉 What You Learned
#
# ✅ **LangChain** is a framework that simplifies building LLM applications
#
# ✅ **Architecture** is modular: loaders, splitters, embeddings, vector stores, chains
#
# ✅ **Documents** contain `page_content` (text) and `metadata` (information about the text)
#
# ✅ **LCEL** uses the `|` operator to chain components together
#
# ✅ **Chains** connect multiple components to create complex workflows
#
# ✅ LangChain **dramatically reduces code** compared to manual implementations
#
# ### 🔰 For Beginners
# You now understand:
# - What LangChain is and why it's useful
# - How to set up your environment
# - Basic concepts: Documents and Chains
# - How to make your first LLM call
#
# ### 🎓 For Intermediate Learners
# You now understand:
# - LangChain's package structure (1.0+ reorganization)
# - LCEL internals and advantages
# - Metadata usage for filtering and citation
# - Batch processing for efficiency
#
#
#
#
# ## 🎓 Additional Resources
#
# - [Official LangChain Documentation](https://python.langchain.com/docs/)
# - [LCEL Guide](https://python.langchain.com/docs/expression_language/)
# - [LangChain GitHub](https://github.com/langchain-ai/langchain)
#
# ---
#
# **Ready for more? Continue to Notebook 02: Document Loaders! 🚀**
