# %% [markdown]
# # ✂️ Text Splitting Strategies
# ---
#
# ## 📖 Table of Contents
#
# 1. [Why Split Text?](#why-split)
# 2. [RecursiveCharacterTextSplitter](#recursive-splitter)
# 3. [CharacterTextSplitter](#character-splitter)
# 4. [HTMLHeaderTextSplitter](#html-splitter)
# 5. [RecursiveJsonSplitter](#json-splitter)
# 6. [TokenTextSplitter](#token-splitter)
# 7. [Chunk Size & Overlap Optimization](#optimization)
# 8. [Comparison & Best Practices](#comparison)
# 9. [Summary & Exercises](#summary)
#
# ---

# %%
# Setup
from pathlib import Path
from dotenv import load_dotenv
load_dotenv()

print("✅ Environment ready")
# Out:
# ✅ Environment ready

# %% [markdown]
# <a id="why-split"></a>
# ## 1. Why Split Text? 🤔
#
# ### 🔰 BEGINNER EXPLANATION
#
# Imagine you have a 200-page book and someone asks: *"What did the author say about machine learning on page 87?"*
#
# **Problem:** LLMs have a limited "attention span" (context window):
# - GPT-3.5-Turbo: ~4,000 tokens (~16,000 characters)
# - GPT-4: ~8,000 tokens (~32,000 characters)
# - You **can't** fit a whole book in one query!
#
# **Solution:** Split the book into smaller **chunks**:
# 1. Each chunk is small enough for the LLM
# 2. Search finds the **relevant chunks** (like page 87)
# 3. Only send those chunks to the LLM
#
# ### The Challenge
#
# If you split text randomly:
# ```
# ❌ BAD SPLIT:
# Chunk 1: "The transformer architecture revolutionized NLP. It uses self-att"
# Chunk 2: "ention mechanisms to process sequences in parallel. This allows..."
# ```
#
# The word "attention" is cut in half! 😱
#
# **Good splitters** respect boundaries (paragraphs, sentences, words):
# ```
# ✅ GOOD SPLIT:
# Chunk 1: "The transformer architecture revolutionized NLP. It uses self-attention mechanisms."
# Chunk 2: "Self-attention allows the model to process sequences in parallel. This improves speed..."
# ```
#
# ### 🎓 INTERMEDIATE: Trade-offs
#
# | Aspect | Small Chunks (500 chars) | Large Chunks (2000 chars) |
# |--------|-------------------------|---------------------------|
# | **Precision** | High (very specific) | Lower (more general) |
# | **Context** | Less context | More context |
# | **Retrieval Quality** | More precise matches | May include noise |
# | **# of Chunks** | More chunks = more storage | Fewer chunks |
# | **Best for** | Q&A, facts, technical docs | Long-form, narrative content |

# %% [markdown]
# <a id="recursive-splitter"></a>
# ## 2. RecursiveCharacterTextSplitter ⭐
#
# ### 🔰 BEGINNER: The Default Choice
#
# **RecursiveCharacterTextSplitter** is your go-to splitter for 90% of cases.
#
# **How it works:**
# 1. Tries to split on **double newlines** (\n\n) → paragraphs
# 2. If chunks still too big, splits on **single newlines** (\n) → lines
# 3. If still too big, splits on **periods** (.) → sentences
# 4. If still too big, splits on **spaces** ( ) → words
# 5. Last resort: splits on **characters**
#
# This preserves meaning as much as possible!

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_community.document_loaders import TextLoader

# %%
# Load our sample text
txt_path = "sample_data/notes.txt"

# %%
loader = TextLoader(txt_path)
documents = loader.load()
documents
# Out:
# [Document(metadata={'source': 'sample_data/notes.txt'}, page_content='LANGCHAIN STUDY NOTES - RAG IMPLEMENTATION\n==========================================\n\nDate: January 15, 2025\nTopic: Retrieval-Augmented Generation with LangChain 1.0+\n\n\nCORE CONCEPTS\n-------------\n\n1. Document Object Structure\n   - page_content: The actual text content\n   - metadata: Dictionary with additional information (source, page, date, etc.)\n   - id: Unique identifier (optional)\n\n2. LCEL (LangChain Expression Language)\n   - Uses pipe operator | to chain components\n   - More readable than nested function calls\n   - Better error handling and debugging\n   - Example: retriever | format_docs | prompt | llm | parser\n\n3. Vector Similarity Search\n   - Converts text to high-dimensional vectors (embeddings)\n   - Uses distance metrics: cosine similarity, Euclidean distance, dot product\n   - Finds semantically similar documents, not just keyword matches\n   - Typical embedding dimensions: 384 (small), 768 (medium), 1536 (large)\n\n\nTEXT SPLITTING STRATEGIES\n--------------------------\n\nRecursiveCharacterTextSplitter (RECOMMENDED)\n- Tries to split on semantic boundaries\n- Order: double newline â†’ newline â†’ period â†’ space â†’ character\n- Best for general text and documentation\n- Configuration: chunk_size=1000, chunk_overlap=200\n\nCharacterTextSplitter\n- Simple splitting on a single separator\n- Use for basic cases or when speed is critical\n- Less sophisticated than recursive splitter\n\nHTMLHeaderTextSplitter\n- Splits HTML based on header tags (h1, h2, h3)\n- Preserves document structure in metadata\n- Ideal for web content and documentation\n\nTokenTextSplitter\n- Splits based on token count, not characters\n- More accurate for LLM context window limits\n- Uses tiktoken for OpenAI models\n\n\nCHUNK SIZE GUIDELINES\n----------------------\n\nContent Type          | Chunk Size | Overlap | Notes\n----------------------|------------|---------|---------------------------\nGeneral Text          | 1000 chars | 200     | Default recommendation\nTechnical Docs        | 500-800    | 100-150 | Precision over context\nSource Code           | 200-400    | 50-100  | Function/class level\nLong Articles         | 1500-2000  | 300     | More context needed\nConversational Data   | 100-200    | 20      | Short exchanges\n\n\nEMBEDDING MODELS COMPARISON\n----------------------------\n\nOpenAI text-embedding-3-small\n- Dimensions: 1536\n- Cost: $0.00002 per 1K tokens\n- MTEB Score: 62.3%\n- Best for: Production applications with budget\n\nOpenAI text-embedding-3-large\n- Dimensions: 3072\n- Cost: $0.00013 per 1K tokens\n- MTEB Score: 64.6%\n- Best for: Highest quality requirements\n\nHuggingFace all-MiniLM-L6-v2\n- Dimensions: 384\n- Cost: FREE (runs locally)\n- MTEB Score: ~56%\n- Best for: Learning, development, privacy-critical apps\n\nHuggingFace all-mpnet-base-v2\n- Dimensions: 768\n- Cost: FREE (runs locally)\n- MTEB Score: 57.8%\n- Best for: Best quality among free options\n\nGoogle Gemini embedding-001\n- Dimensions: 768\n- Cost: Free tier available\n- Best for: Google Cloud ecosystem\n\n\nVECTOR STORE SELECTION\n-----------------------\n\nInMemoryVectorStore\nPros: Simple setup, no dependencies, fast for small datasets\nCons: No persistence, limited to memory size\nUse for: Testing, development, small demos\n\nFAISS (Facebook AI Similarity Search)\nPros: Very fast, scales to billions, runs locally, persistent\nCons: Limited metadata filtering, manual index management\nUse for: Production apps, large datasets, when speed matters\n\nChroma\nPros: Easy to use, excellent metadata filtering, auto-persistence\nCons: Slower than FAISS at scale, memory limitations\nUse for: Development, medium datasets, when metadata filtering is important\n\nQdrant\nPros: Production-ready, excellent filtering, hybrid search, scalable\nCons: More complex setup, requires server for production\nUse for: Enterprise applications, complex filtering needs\n\nPineco ...

# %%
len(documents[0].page_content)
# Out:
# 8639

# %%
documents[0].page_content[:500]
# Out:
# 'LANGCHAIN STUDY NOTES - RAG IMPLEMENTATION\n==========================================\n\nDate: January 15, 2025\nTopic: Retrieval-Augmented Generation with LangChain 1.0+\n\n\nCORE CONCEPTS\n-------------\n\n1. Document Object Structure\n   - page_content: The actual text content\n   - metadata: Dictionary with additional information (source, page, date, etc.)\n   - id: Unique identifier (optional)\n\n2. LCEL (LangChain Expression Language)\n   - Uses pipe operator | to chain components\n   - More readable than'

# %%
splitter = RecursiveCharacterTextSplitter(
        chunk_size=1000,        # Maximum chunk size in characters
        chunk_overlap=200,      # Overlap between chunks
        length_function=len,    # How to measure length
        separators=["\n\n", "\n", ". ", " ", ""]  # Try these in order
    )
chunks = splitter.split_documents(documents)
chunks
# Out:
# [Document(metadata={'source': 'sample_data/notes.txt'}, page_content='LANGCHAIN STUDY NOTES - RAG IMPLEMENTATION\n==========================================\n\nDate: January 15, 2025\nTopic: Retrieval-Augmented Generation with LangChain 1.0+\n\n\nCORE CONCEPTS\n-------------\n\n1. Document Object Structure\n   - page_content: The actual text content\n   - metadata: Dictionary with additional information (source, page, date, etc.)\n   - id: Unique identifier (optional)\n\n2. LCEL (LangChain Expression Language)\n   - Uses pipe operator | to chain components\n   - More readable than nested function calls\n   - Better error handling and debugging\n   - Example: retriever | format_docs | prompt | llm | parser\n\n3. Vector Similarity Search\n   - Converts text to high-dimensional vectors (embeddings)\n   - Uses distance metrics: cosine similarity, Euclidean distance, dot product\n   - Finds semantically similar documents, not just keyword matches\n   - Typical embedding dimensions: 384 (small), 768 (medium), 1536 (large)\n\n\nTEXT SPLITTING STRATEGIES\n--------------------------'),
#  Document(metadata={'source': 'sample_data/notes.txt'}, page_content='TEXT SPLITTING STRATEGIES\n--------------------------\n\nRecursiveCharacterTextSplitter (RECOMMENDED)\n- Tries to split on semantic boundaries\n- Order: double newline â†’ newline â†’ period â†’ space â†’ character\n- Best for general text and documentation\n- Configuration: chunk_size=1000, chunk_overlap=200\n\nCharacterTextSplitter\n- Simple splitting on a single separator\n- Use for basic cases or when speed is critical\n- Less sophisticated than recursive splitter\n\nHTMLHeaderTextSplitter\n- Splits HTML based on header tags (h1, h2, h3)\n- Preserves document structure in metadata\n- Ideal for web content and documentation\n\nTokenTextSplitter\n- Splits based on token count, not characters\n- More accurate for LLM context window limits\n- Uses tiktoken for OpenAI models\n\n\nCHUNK SIZE GUIDELINES\n----------------------'),
#  Document(metadata={'source': 'sample_data/notes.txt'}, page_content='TokenTextSplitter\n- Splits based on token count, not characters\n- More accurate for LLM context window limits\n- Uses tiktoken for OpenAI models\n\n\nCHUNK SIZE GUIDELINES\n----------------------\n\nContent Type          | Chunk Size | Overlap | Notes\n----------------------|------------|---------|---------------------------\nGeneral Text          | 1000 chars | 200     | Default recommendation\nTechnical Docs        | 500-800    | 100-150 | Precision over context\nSource Code           | 200-400    | 50-100  | Function/class level\nLong Articles         | 1500-2000  | 300     | More context needed\nConversational Data   | 100-200    | 20      | Short exchanges\n\n\nEMBEDDING MODELS COMPARISON\n----------------------------\n\nOpenAI text-embedding-3-small\n- Dimensions: 1536\n- Cost: $0.00002 per 1K tokens\n- MTEB Score: 62.3%\n- Best for: Production applications with budget'),
#  Document(metadata={'source': 'sample_data/notes.txt'}, page_content='OpenAI text-embedding-3-small\n- Dimensions: 1536\n- Cost: $0.00002 per 1K tokens\n- MTEB Score: 62.3%\n- Best for: Production applications with budget\n\nOpenAI text-embedding-3-large\n- Dimensions: 3072\n- Cost: $0.00013 per 1K tokens\n- MTEB Score: 64.6%\n- Best for: Highest quality requirements\n\nHuggingFace all-MiniLM-L6-v2\n- Dimensions: 384\n- Cost: FREE (runs locally)\n- MTEB Score: ~56%\n- Best for: Learning, development, privacy-critical apps\n\nHuggingFace all-mpnet-base-v2\n- Dimensions: 768\n- Cost: FREE (runs locally)\n- MTEB Score: 57.8%\n- Best for: Best quality among free options\n\nGoogle Gemini embedding-001\n- Dimensions: 768\n- Cost: Free tier available\n- Best for: Google Cloud ecosystem\n\n\nVECTOR STORE SELECTION\n-----------------------\n\nInMemoryVectorStore\nPros: Simple setup, no dependencies, fast for small datasets\nCons: No persistence, limited to memory size\nUse for: Testing, development, small demos'),
#  Document(metadata={'source': 'sample_data/notes.txt'}, page_content='InMemoryVectorStore\nPros: Simple setup, no dependencies, fast for small datasets\nCons: No persistence, limited to memory size\nUse for: Testing, development, small demos\n\nFAISS (Facebook AI Similarity Search)\nPros: Very fast, scales to billions, runs locally, persistent\nCons: Limited metadata filtering, manual index management\nUse for: Production apps, large datasets, when speed matters\n\nChroma\nPros: Easy to use, excellent metadata filtering, auto-persistence\nCons: Slower than FAISS at scale, memory limitations\nUse for: Development, medium datasets, when metadata filtering is important\n\nQdrant\nPros: Production-ready, excellent filtering, hybrid search, scalable\nCons: More complex setup, requires server for production\nUse for: Enterprise applications, complex filtering needs\n\nPinecone\nPros: Fully managed, highly scalable, great performance\nCons: Costs money, vendor lock-in, requires internet\nUse for: Production apps where managed service is preferred'),
#  Document(metadata={'source': 'sample_data/notes.txt'}, page_content='Pinecone\nPros: Fully managed, highly scalable, great performance\nCons: Costs money, vendor lock-in, requires internet\nUse for: Production apps where managed service is preferred\n\n\nRETRIEVAL STRATEGIES\n---------------------\n\nSimilarity Search\n- Default method: returns top-k most similar documents\n- Fast and straightforward\n- May return redundant/similar results\n- Parameters: k (number of results), score_threshold (minimum similarity)\n\nMaximum Marginal Relevance (MMR)\n- Balances relevance and diversity\n- Reduces redundancy in results\n- Parameters:\n  * k: final number of results\n  * fetch_k: initial pool size (e.g., 20)\n  * lambda_mult: 0=diverse, 1=relevant, 0.5=balanced\n\nCustom Retrievers\n- Use @chain decorator to create custom retrieval logic\n- Can combine multiple strategies\n- Useful for:\n  * Hybrid search (vector + keyword)\n  * Re-ranking\n  * Metadata-based filtering\n  * Business logic integration\n\n\nCOMMON MISTAKES TO AVOID\n-------------------------'),
#  Document(metadata={'source': 'sample_data/notes.txt'}, page_content='COMMON MISTAKES TO AVOID\n-------------------------\n\n1. Hardcoding API keys â†’ Use environment variables\n2. Not persisting vector stores â†’ Save and reuse to avoid re-embedding\n3. Ignoring metadata â†’ Maintain source information for citation\n4. Random chunk sizes â†’ Choose based on content type and testing\n5. Not monitoring costs â†’ Track API usage before production\n6. Using deprecated syntax â†’ Use .invoke() not .run() or .get_relevant_documents()\n7. Loading huge files at once â†’ Use lazy loading for large documents\n8. No error handling â†’ Wrap operations in try-except blocks\n9. Not testing retrieval quality â†’ Create evaluation dataset\n10. Forgetting overlap â†’ Use 10-20% overlap to preserve context\n\n\nPRODUCTION CHECKLIST\n---------------------'),
#  Document(metadata={'source': 'sample_data/notes.txt'}, page_content='PRODUCTION CHECKLIST\n---------------------\n\nBefore Deployment:\nâ–¡ Environment variables configured (.env file)\nâ–¡ API keys secured (not in code)\nâ–¡ Vector store persistent (saved to disk)\nâ–¡ Error handling implemented\nâ–¡ Costs estimated and monitored\nâ–¡ Retrieval quality tested\nâ–¡ Rate limiting configured\nâ–¡ Logging implemented\nâ–¡ Backup strategy for vector stores\nâ–¡ Documentation written\nâ–¡ Test suite created\nâ–¡ Performance benchmarks established\n\n\nCODE SNIPPETS\n--------------\n\nBasic RAG Chain (LCEL):\n```python\nfrom langchain_core.runnables import RunnablePassthrough\nfrom langchain_core.output_parsers import StrOutputParser\n\ndef format_docs(docs):\n    return "\\n\\n".join(doc.page_content for doc in docs)\n\nchain = (\n    {"context": retriever | format_docs, "question": RunnablePassthrough()}\n    | prompt\n    | llm\n    | StrOutputParser()\n)\n\nanswer = chain.invoke("What is RAG?")\n```'),
#  Document(metadata={'source': 'sample_data/notes.txt'}, page_content='chain = (\n    {"context": retriever | format_docs, "question": RunnablePassthrough()}\n    | prompt\n    | llm\n    | StrOutputParser()\n)\n\nanswer = chain.invoke("What is RAG?")\n```\n\nLoading Multiple File Types:\n```python\nfrom pathlib import Path\nfrom langchain_community.document_loaders import (\n    PyPDFLoader, CSVLoader, JSONLoader, TextLoader\n)\n\nall_docs = []\n\n# PDFs\nfor pdf in Path("docs").glob("*.pdf"):\n    all_docs.extend(PyPDFLoader(str(pdf)).load())\n\n# CSVs\nfor csv in Path("data").glob("*.csv"):\n    all_docs.extend(CSVLoader(str(csv)).load())\n\n# Text files\nfor txt in Path("notes").glob("*.txt"):\n    all_docs.extend(TextLoader(str(txt)).load())\n```\n\nSimilarity Search with Scores:\n```python\nresults = vectorstore.similarity_search_with_score(\n    query="What is machine learning?",\n    k=4\n)\n\nfor doc, score in results:\n    print(f"Score: {score:.4f} | {doc.page_content[:100]}...")\n```\n\n\nRESOURCES\n---------'),
#  Document(metadata={'source': 'sample_data/notes.txt'}, page_content='for doc, score in results:\n    print(f"Score: {score:.4f} | {doc.page_content[:100]}...")\n```\n\n\nRESOURCES\n---------\n\nOfficial Documentation:\n- LangChain Docs: https://python.langchain.com/docs/\n- OpenAI API: https://platform.openai.com/docs\n- FAISS: https://github.com/facebookresearch/faiss\n\nTutorials and Guides:\n- LangChain LCEL Guide: https://python.langchain.com/docs/expression_language/\n- RAG Best Practices: Search for "RAG best practices" in current docs\n- Embedding Models: https://huggingface.co/spaces/mteb/leaderboard\n\nCommunity:\n- LangChain Discord\n- r/LangChain on Reddit\n- Stack Overflow (tag: langchain)\n\n\nNEXT STEPS\n----------'),
#  Document(metadata={'source': 'sample_data/notes.txt'}, page_content='Community:\n- LangChain Discord\n- r/LangChain on Reddit\n- Stack Overflow (tag: langchain)\n\n\nNEXT STEPS\n----------\n\n1. Practice with different document types (PDF, CSV, JSON, HTML)\n2. Experiment with chunk sizes for your specific use case\n3. Compare embedding models (OpenAI vs HuggingFace)\n4. Try different vector stores (FAISS, Chroma, Qdrant)\n5. Implement evaluation metrics\n6. Build a complete application with proper error handling\n7. Optimize for production (caching, rate limiting, monitoring)\n8. Explore advanced techniques (re-ranking, query transformation, hybrid search)\n\n\nKEY TAKEAWAYS\n-------------'),
#  Document(metadata={'source': 'sample_data/notes.txt'}, page_content='KEY TAKEAWAYS\n-------------\n\nâœ“ RAG = Retrieval + Context + Generation\nâœ“ Good chunking strategy is critical for quality\nâœ“ LCEL makes chain building more readable\nâœ“ Always persist vector stores to save costs\nâœ“ Test retrieval quality before optimizing generation\nâœ“ Monitor costs throughout development\nâœ“ Start simple, iterate based on metrics\nâœ“ Metadata is your friend for filtering and citation\nâœ“ No single "best" configuration - test for your use case\nâœ“ Production requires error handling, monitoring, and optimization\n\n\nEnd of Notes')]

# %% [markdown]
# chunk_overlap is taken roughly 10-20% of the chunk_size

# %%
print(f"✂️ Split into {len(chunks)} chunks\n")
    
    # Examine first 3 chunks
for i, chunk in enumerate(chunks[:3], 1):
    print(f"{'='*70}")
    print(f"Chunk {i} ({len(chunk.page_content)} chars):")
    print(f"{'='*70}")
    print(chunk.page_content[:300] + "..." if len(chunk.page_content) > 300 else chunk.page_content)
    print()
# Out:
# ✂️ Split into 12 chunks
#
# ======================================================================
# Chunk 1 (991 chars):
# ======================================================================
# LANGCHAIN STUDY NOTES - RAG IMPLEMENTATION
# ==========================================
#
# Date: January 15, 2025
# Topic: Retrieval-Augmented Generation with LangChain 1.0+
#
#
# CORE CONCEPTS
# -------------
#
# 1. Document Object Structure
#    - page_content: The actual text content
#    - metadata: Dictionary wit...
#
# ======================================================================
# Chunk 2 (809 chars):
# ======================================================================
# TEXT SPLITTING STRATEGIES
# --------------------------
#
# RecursiveCharacterTextSplitter (RECOMMENDED)
# - Tries to split on semantic boundaries
# - Order: double newline â†’ newline â†’ period â†’ space â†’ character
# - Best for general text and documentation
# - Configuration: chunk_size=1000, chunk_overlap=...
#
# ======================================================================
# Chunk 3 (864 chars):
# ======================================================================
# TokenTextSplitter
# - Splits based on token count, not characters
# - More accurate for LLM context window limits
# - Uses tiktoken for OpenAI models
#
#
# CHUNK SIZE GUIDELINES
# ----------------------
#
# Content Type          | Chunk Size | Overlap | Notes
# ----------------------|------------|---------|---------...

# %% [markdown]
# ### 🔰 Understanding Chunk Overlap
#
# **Why overlap?** To preserve context across boundaries.
#
# **Example without overlap:**
# ```
# Chunk 1: "...introducing the transformer architecture."
# Chunk 2: "The model uses multi-head attention..."
# ```
# → Missing connection between "transformer" and "multi-head attention"
#
# **Example with overlap:**
# ```
# Chunk 1: "...introducing the transformer architecture. The model uses..."
# Chunk 2: "...transformer architecture. The model uses multi-head attention..."
# ```
# → Both chunks have the connection!

# %%
# Demonstrate overlap
if Path(txt_path).exists():
    docs = TextLoader(txt_path).load()
    
    # Splitter with overlap
    splitter_with_overlap = RecursiveCharacterTextSplitter(
        chunk_size=500,
        chunk_overlap=100  # 100 chars overlap
    )
    
    chunks = splitter_with_overlap.split_documents(docs)
    
    print("🔍 Examining overlap between chunks:\n")
    
    # Show overlap between chunk 1 and 2
    if len(chunks) >= 2:
        chunk1_end = chunks[0].page_content[-150:]
        chunk2_start = chunks[1].page_content[:150]
        
        print("Chunk 1 ending:")
        print(f"  ...{chunk1_end}")
        print("\nChunk 2 beginning:")
        print(f"  {chunk2_start}...")
        print("\n💡 Notice the overlap? There should have been overlap here, but it's not immediately obvious.")
# Out:
# 🔍 Examining overlap between chunks:
#
# Chunk 1 ending:
#   ...ontent: The actual text content
#    - metadata: Dictionary with additional information (source, page, date, etc.)
#    - id: Unique identifier (optional)
#
# Chunk 2 beginning:
#   2. LCEL (LangChain Expression Language)
#    - Uses pipe operator | to chain components
#    - More readable than nested function calls
#    - Better error ...
#
# 💡 Notice the overlap? There should have been overlap here, but it's not immediately obvious.

# %% [markdown]
# The overlap is deprioritised as there is a natural semantic boundary here which will be prioritised by design.

# %%
mysplitter = RecursiveCharacterTextSplitter(
    chunk_size=500,
    chunk_overlap=100
)

chunked_chunks = mysplitter.split_documents(documents)

chunked_chunks[2].page_content[-150:]
# Out:
# 'just keyword matches\n   - Typical embedding dimensions: 384 (small), 768 (medium), 1536 (large)\n\n\nTEXT SPLITTING STRATEGIES\n--------------------------'

# %%
chunked_chunks[3].page_content[:150]
# Out:
# 'TEXT SPLITTING STRATEGIES\n--------------------------\n\nRecursiveCharacterTextSplitter (RECOMMENDED)\n- Tries to split on semantic boundaries\n- Order: do'

# %% [markdown]
# Notice the overlap here, it is clearly visible.

# %% [markdown]
# ### 🎓 INTERMEDIATE: Custom Separators for Code

# %%
# Example: Splitting Python code
from langchain_text_splitters import Language, RecursiveCharacterTextSplitter

# Python code example
python_code = '''
def calculate_total(items):
    """Calculate total price of items."""
    total = 0
    for item in items:
        total += item['price']
    return total

def apply_discount(total, discount_percent):
    """Apply discount to total."""
    discount = total * (discount_percent / 100)
    return total - discount

class ShoppingCart:
    def __init__(self):
        self.items = []
    
    def add_item(self, item):
        self.items.append(item)
'''

# Python-aware splitter
python_splitter = RecursiveCharacterTextSplitter.from_language(
    language=Language.PYTHON,
    chunk_size=200,
    chunk_overlap=50
)

code_chunks = python_splitter.split_text(python_code)

print(f"✂️ Split code into {len(code_chunks)} chunks:\n")
for i, chunk in enumerate(code_chunks, 1):
    print(f"Chunk {i}: {len(chunk)} characters")
    print(chunk)
    print("-" * 50)
# Out:
# ✂️ Split code into 3 chunks:
#
# Chunk 1: 154 characters
# def calculate_total(items):
#     """Calculate total price of items."""
#     total = 0
#     for item in items:
#         total += item['price']
#     return total
# --------------------------------------------------
# Chunk 2: 155 characters
# def apply_discount(total, discount_percent):
#     """Apply discount to total."""
#     discount = total * (discount_percent / 100)
#     return total - discount
# --------------------------------------------------
# Chunk 3: 130 characters
# class ShoppingCart:
#     def __init__(self):
#         self.items = []
#
#     def add_item(self, item):
#         self.items.append(item)
# --------------------------------------------------

# %%
# Example: Splitting Python code
from langchain_text_splitters import Language, RecursiveCharacterTextSplitter

# Python code example
python_code = '''
def calculate_total(items):
    """Calculate total price of items."""
    total = 0
    for item in items:
        total += item['price']
    return total

def apply_discount(total, discount_percent):
    """Apply discount to total."""
    discount = total * (discount_percent / 100)
    return total - discount

class ShoppingCart:
    def __init__(self):
        self.items = []
    
    def add_item(self, item):
        self.items.append(item)
'''

# Python-aware splitter
python_splitter = RecursiveCharacterTextSplitter.from_language(
    language=Language.PYTHON,
    chunk_size=300,
    chunk_overlap=75
)

code_chunks = python_splitter.split_text(python_code)

print(f"✂️ Split code into {len(code_chunks)} chunks:\n")
for i, chunk in enumerate(code_chunks, 1):
    print(f"Chunk {i}: {len(chunk)} characters")
    print(chunk)
    print("-" * 50)
# Out:
# ✂️ Split code into 3 chunks:
#
# Chunk 1: 154 characters
# def calculate_total(items):
#     """Calculate total price of items."""
#     total = 0
#     for item in items:
#         total += item['price']
#     return total
# --------------------------------------------------
# Chunk 2: 155 characters
# def apply_discount(total, discount_percent):
#     """Apply discount to total."""
#     discount = total * (discount_percent / 100)
#     return total - discount
# --------------------------------------------------
# Chunk 3: 130 characters
# class ShoppingCart:
#     def __init__(self):
#         self.items = []
#
#     def add_item(self, item):
#         self.items.append(item)
# --------------------------------------------------

# %%
# Example: Splitting Python code
from langchain_text_splitters import Language, RecursiveCharacterTextSplitter

# Python code example
python_code = '''
def process_large_dataset(data):
    """Pretend this function is very large."""

    result = []

    for item in data:
        if item > 0:
            result.append(item * 2)
        else:
            result.append(0)

    # -----------------------------
    # Long block begins here
    # -----------------------------
    text = """
    Lorem ipsum dolor sit amet, consectetur adipiscing elit.
    Sed do eiusmod tempor incididunt ut labore et dolore magna aliqua.
    Ut enim ad minim veniam, quis nostrud exercitation ullamco laboris.
    Duis aute irure dolor in reprehenderit in voluptate velit esse.
    Excepteur sint occaecat cupidatat non proident.
    Sunt in culpa qui officia deserunt mollit anim id est laborum.

    Lorem ipsum dolor sit amet, consectetur adipiscing elit.
    Sed do eiusmod tempor incididunt ut labore et dolore magna aliqua.
    Ut enim ad minim veniam, quis nostrud exercitation ullamco laboris.
    Duis aute irure dolor in reprehenderit in voluptate velit esse.
    Excepteur sint occaecat cupidatat non proident.
    Sunt in culpa qui officia deserunt mollit anim id est laborum.

    Lorem ipsum dolor sit amet, consectetur adipiscing elit.
    Sed do eiusmod tempor incididunt ut labore et dolore magna aliqua.
    Ut enim ad minim veniam, quis nostrud exercitation ullamco laboris.
    Duis aute irure dolor in reprehenderit in voluptate velit esse.
    Excepteur sint occaecat cupidatat non proident.
    Sunt in culpa qui officia deserunt mollit anim id est laborum.

    Lorem ipsum dolor sit amet, consectetur adipiscing elit.
    Sed do eiusmod tempor incididunt ut labore et dolore magna aliqua.
    Ut enim ad minim veniam, quis nostrud exercitation ullamco laboris.
    Duis aute irure dolor in reprehenderit in voluptate velit esse.
    Excepteur sint occaecat cupidatat non proident.
    Sunt in culpa qui officia deserunt mollit anim id est laborum.
    """

    return result


def small_function():
    return "Done"
'''

# Python-aware splitter
python_splitter = RecursiveCharacterTextSplitter.from_language(
    language=Language.PYTHON,
    chunk_size=200,
    chunk_overlap=50
)

code_chunks = python_splitter.split_text(python_code)

print(f"✂️ Split code into {len(code_chunks)} chunks:\n")
for i, chunk in enumerate(code_chunks, 1):
    print(f"Chunk {i}: {len(chunk)} characters")
    print(chunk)
    print("-" * 50)
# Out:
# ✂️ Split code into 16 chunks:
#
# Chunk 1: 96 characters
# def process_large_dataset(data):
#     """Pretend this function is very large."""
#
#     result = []
# --------------------------------------------------
# Chunk 2: 134 characters
# result = []
#
#     for item in data:
#         if item > 0:
#             result.append(item * 2)
#         else:
#             result.append(0)
# --------------------------------------------------
# Chunk 3: 172 characters
# # -----------------------------
#     # Long block begins here
#     # -----------------------------
#     text = """
#     Lorem ipsum dolor sit amet, consectetur adipiscing elit.
# --------------------------------------------------
# Chunk 4: 138 characters
# Sed do eiusmod tempor incididunt ut labore et dolore magna aliqua.
#     Ut enim ad minim veniam, quis nostrud exercitation ullamco laboris.
# --------------------------------------------------
# Chunk 5: 182 characters
# Duis aute irure dolor in reprehenderit in voluptate velit esse.
#     Excepteur sint occaecat cupidatat non proident.
#     Sunt in culpa qui officia deserunt mollit anim id est laborum.
# --------------------------------------------------
# Chunk 6: 127 characters
# Lorem ipsum dolor sit amet, consectetur adipiscing elit.
#     Sed do eiusmod tempor incididunt ut labore et dolore magna aliqua.
# --------------------------------------------------
# Chunk 7: 187 characters
# Ut enim ad minim veniam, quis nostrud exercitation ullamco laboris.
#     Duis aute irure dolor in reprehenderit in voluptate velit esse.
#     Excepteur sint occaecat cupidatat non proident.
# --------------------------------------------------
# Chunk 8: 62 characters
# Sunt in culpa qui officia deserunt mollit anim id est laborum.
# --------------------------------------------------
# Chunk 9: 127 characters
# Lorem ipsum dolor sit amet, consectetur adipiscing elit.
#     Sed do eiusmod tempor incididunt ut labore et dolore magna aliqua.
# --------------------------------------------------
# Chunk 10: 187 characters
# Ut enim ad minim veniam, quis nostrud exercitation ullamco laboris.
#     Duis aute irure dolor in reprehenderit in voluptate velit esse.
#     Excepteur sint occaecat cupidatat non proident.
# --------------------------------------------------
# Chunk 11: 62 characters
# Sunt in culpa qui officia deserunt mollit anim id est laborum.
# --------------------------------------------------
# Chunk 12: 127 characters
# Lorem ipsum dolor sit amet, consectetur adipiscing elit.
#     Sed do eiusmod tempor incididunt ut labore et dolore magna aliqua.
# --------------------------------------------------
# Chunk 13: 187 characters
# Ut enim ad minim veniam, quis nostrud exercitation ullamco laboris.
#     Duis aute irure dolor in reprehenderit in voluptate velit esse.
#     Excepteur sint occaecat cupidatat non proident.
# --------------------------------------------------
# Chunk 14: 70 characters
# Sunt in culpa qui officia deserunt mollit anim id est laborum.
#     """
# --------------------------------------------------
# Chunk 15: 13 characters
# return result
# --------------------------------------------------
# Chunk 16: 39 characters
# def small_function():
#     return "Done"
# --------------------------------------------------

# %%
# Example: Splitting Python code
from langchain_text_splitters import Language, RecursiveCharacterTextSplitter

# Python code example
python_code = '''
def process_large_dataset(data):
    """Pretend this function is very large."""

    result = []

    for item in data:
        if item > 0:
            result.append(item * 2)
        else:
            result.append(0)

    # -----------------------------
    # Long block begins here
    # -----------------------------
    text = """
    Lorem ipsum dolor sit amet, consectetur adipiscing elit.
    Sed do eiusmod tempor incididunt ut labore et dolore magna aliqua.
    Ut enim ad minim veniam, quis nostrud exercitation ullamco laboris.
    Duis aute irure dolor in reprehenderit in voluptate velit esse.
    Excepteur sint occaecat cupidatat non proident.
    Sunt in culpa qui officia deserunt mollit anim id est laborum.

    Lorem ipsum dolor sit amet, consectetur adipiscing elit.
    Sed do eiusmod tempor incididunt ut labore et dolore magna aliqua.
    Ut enim ad minim veniam, quis nostrud exercitation ullamco laboris.
    Duis aute irure dolor in reprehenderit in voluptate velit esse.
    Excepteur sint occaecat cupidatat non proident.
    Sunt in culpa qui officia deserunt mollit anim id est laborum.

    Lorem ipsum dolor sit amet, consectetur adipiscing elit.
    Sed do eiusmod tempor incididunt ut labore et dolore magna aliqua.
    Ut enim ad minim veniam, quis nostrud exercitation ullamco laboris.
    Duis aute irure dolor in reprehenderit in voluptate velit esse.
    Excepteur sint occaecat cupidatat non proident.
    Sunt in culpa qui officia deserunt mollit anim id est laborum.

    Lorem ipsum dolor sit amet, consectetur adipiscing elit.
    Sed do eiusmod tempor incididunt ut labore et dolore magna aliqua.
    Ut enim ad minim veniam, quis nostrud exercitation ullamco laboris.
    Duis aute irure dolor in reprehenderit in voluptate velit esse.
    Excepteur sint occaecat cupidatat non proident.
    Sunt in culpa qui officia deserunt mollit anim id est laborum.
    """

    return result


def small_function():
    return "Done"
'''

# Python-aware splitter
python_splitter = RecursiveCharacterTextSplitter.from_language(
    language=Language.PYTHON,
    chunk_size=350,
    chunk_overlap=75
)

code_chunks = python_splitter.split_text(python_code)

print(f"✂️ Split code into {len(code_chunks)} chunks:\n")
for i, chunk in enumerate(code_chunks, 1):
    print(f"Chunk {i}: {len(chunk)} characters")
    print(chunk)
    print("-" * 50)
# Out:
# ✂️ Split code into 11 chunks:
#
# Chunk 1: 219 characters
# def process_large_dataset(data):
#     """Pretend this function is very large."""
#
#     result = []
#
#     for item in data:
#         if item > 0:
#             result.append(item * 2)
#         else:
#             result.append(0)
# --------------------------------------------------
# Chunk 2: 315 characters
# # -----------------------------
#     # Long block begins here
#     # -----------------------------
#     text = """
#     Lorem ipsum dolor sit amet, consectetur adipiscing elit.
#     Sed do eiusmod tempor incididunt ut labore et dolore magna aliqua.
#     Ut enim ad minim veniam, quis nostrud exercitation ullamco laboris.
# --------------------------------------------------
# Chunk 3: 254 characters
# Ut enim ad minim veniam, quis nostrud exercitation ullamco laboris.
#     Duis aute irure dolor in reprehenderit in voluptate velit esse.
#     Excepteur sint occaecat cupidatat non proident.
#     Sunt in culpa qui officia deserunt mollit anim id est laborum.
# --------------------------------------------------
# Chunk 4: 319 characters
# Lorem ipsum dolor sit amet, consectetur adipiscing elit.
#     Sed do eiusmod tempor incididunt ut labore et dolore magna aliqua.
#     Ut enim ad minim veniam, quis nostrud exercitation ullamco laboris.
#     Duis aute irure dolor in reprehenderit in voluptate velit esse.
#     Excepteur sint occaecat cupidatat non proident.
# --------------------------------------------------
# Chunk 5: 114 characters
# Excepteur sint occaecat cupidatat non proident.
#     Sunt in culpa qui officia deserunt mollit anim id est laborum.
# --------------------------------------------------
# Chunk 6: 319 characters
# Lorem ipsum dolor sit amet, consectetur adipiscing elit.
#     Sed do eiusmod tempor incididunt ut labore et dolore magna aliqua.
#     Ut enim ad minim veniam, quis nostrud exercitation ullamco laboris.
#     Duis aute irure dolor in reprehenderit in voluptate velit esse.
#     Excepteur sint occaecat cupidatat non proident.
# --------------------------------------------------
# Chunk 7: 114 characters
# Excepteur sint occaecat cupidatat non proident.
#     Sunt in culpa qui officia deserunt mollit anim id est laborum.
# --------------------------------------------------
# Chunk 8: 319 characters
# Lorem ipsum dolor sit amet, consectetur adipiscing elit.
#     Sed do eiusmod tempor incididunt ut labore et dolore magna aliqua.
#     Ut enim ad minim veniam, quis nostrud exercitation ullamco laboris.
#     Duis aute irure dolor in reprehenderit in voluptate velit esse.
#     Excepteur sint occaecat cupidatat non proident.
# --------------------------------------------------
# Chunk 9: 122 characters
# Excepteur sint occaecat cupidatat non proident.
#     Sunt in culpa qui officia deserunt mollit anim id est laborum.
#     """
# --------------------------------------------------
# Chunk 10: 13 characters
# return result
# --------------------------------------------------
# Chunk 11: 39 characters
# def small_function():
#     return "Done"
# --------------------------------------------------

# %% [markdown]
# <a id="character-splitter"></a>
# ## 3. CharacterTextSplitter
#
# ### 🔰 BEGINNER: Simple Splitting
#
# **CharacterTextSplitter** splits on a single separator (like "\n\n").
# - Simpler than Recursive
# - Less intelligent
# - Use for testing or very simple text
# - Not recommended for Real world things

# %%
from langchain_text_splitters import CharacterTextSplitter

# Sample text with clear paragraph breaks
sample_text = """First paragraph about machine learning.
It has multiple sentences. This is important context.

Second paragraph about deep learning.
Neural networks are powerful. They learn from data.

Third paragraph about transformers.
Attention mechanisms are key. They revolutionized NLP.
"""

# Split on paragraph breaks
simple_splitter = CharacterTextSplitter(
    separator="\n\n",  # Split on double newline (paragraphs)
    chunk_size=100,
    chunk_overlap=20
)

chunks = simple_splitter.split_text(sample_text)

print(f"Split into {len(chunks)} chunks:\n")
for i, chunk in enumerate(chunks, 1):
    print(f"Chunk {i}: {chunk.strip()}\n")
# Out:
# Split into 3 chunks:
#
# Chunk 1: First paragraph about machine learning.
# It has multiple sentences. This is important context.
#
# Chunk 2: Second paragraph about deep learning.
# Neural networks are powerful. They learn from data.
#
# Chunk 3: Third paragraph about transformers.
# Attention mechanisms are key. They revolutionized NLP.

# %% [markdown]
# <a id="html-splitter"></a>
# ## 4. HTMLHeaderTextSplitter 🌐
#
# ### 🔰 BEGINNER: Structure-Aware Splitting
#
# **HTMLHeaderTextSplitter** splits HTML based on headers (h1, h2, h3).
# - Preserves document structure
# - Adds header information to metadata
# - Perfect for documentation

# %%
from langchain_text_splitters import HTMLHeaderTextSplitter
from pathlib import Path

# Load the HTML blog post
html_path = "sample_data/blog_post.html"

if Path(html_path).exists():
    # Read HTML content
    with open(html_path, 'r', encoding='utf-8') as f:
        html_content = f.read()
    
    # Define headers to split on
    headers_to_split_on = [
        ("h1", "Title"),
        ("h2", "Section"),
        ("h3", "Subsection"),
    ]
    
    # Create splitter
    html_splitter = HTMLHeaderTextSplitter(headers_to_split_on=headers_to_split_on)
    
    # Split the HTML
    html_chunks = html_splitter.split_text(html_content)
    
    print(f"✂️ Split HTML into {len(html_chunks)} sections\n")
    
    # Show first 3 sections with metadata
    for i, chunk in enumerate(html_chunks[:3], 1):
        print(f"{'='*70}")
        print(f"Section {i}:")
        print(f"Metadata: {chunk.metadata}")
        print(f"Content (first 200 chars): {chunk.page_content[:200]}...")
        print()
else:
    print(f"❌ HTML file not found: {html_path}")
# Out:
# ✂️ Split HTML into 48 sections
#
# ======================================================================
# Section 1:
# Metadata: {'Title': 'Building Intelligent Applications with RAG'}
# Content (first 200 chars): Building Intelligent Applications with RAG...
#
# ======================================================================
# Section 2:
# Metadata: {'Title': 'Building Intelligent Applications with RAG'}
# Content (first 200 chars): | |
# By Dr. Amanda Foster
# January 15, 2025
# 12 min read...
#
# ======================================================================
# Section 3:
# Metadata: {'Title': 'Building Intelligent Applications with RAG', 'Section': 'Introduction'}
# Content (first 200 chars): Introduction...

# %% [markdown]
# <a id="json-splitter"></a>
# ## 5. RecursiveJsonSplitter 📦
#
# ### 🔰 BEGINNER: Splitting JSON Data
#
# **RecursiveJsonSplitter** splits JSON while preserving structure.

# %%
from langchain_text_splitters import RecursiveJsonSplitter
import json

# Load JSON data
json_path = "sample_data/api_response.json"

if Path(json_path).exists():
    with open(json_path, 'r') as f:
        json_data = json.load(f)
    
    # Create splitter
    json_splitter = RecursiveJsonSplitter(
        max_chunk_size=1000,
        min_chunk_size=100
    ) #10-15% rule applies here too
    
    # Split
    json_chunks = json_splitter.split_text(
        json_data=json_data,
        convert_lists=True
    )
    
    print(f"✂️ Split JSON into {len(json_chunks)} chunks\n")
    
    # Show first chunk
    print("First chunk:")
    print(json.dumps(json_chunks[0], indent=2)[:500] + "...")
else:
    print(f"❌ JSON file not found: {json_path}")
# Out:
# ✂️ Split JSON into 7 chunks
#
# First chunk:
# "{\"api_version\": \"v2.0\", \"timestamp\": \"2025-01-15T10:30:00Z\", \"total_results\": 5, \"articles\": {\"0\": {\"id\": \"article_001\", \"title\": \"Introduction to Retrieval-Augmented Generation (RAG)\", \"author\": \"Dr. Sarah Chen\", \"published_date\": \"2025-01-10\", \"category\": \"Machine Learning\", \"tags\": {\"0\": \"RAG\", \"1\": \"LLM\", \"2\": \"NLP\", \"3\": \"AI\"}, \"summary\": \"Retrieval-Augmented Generation (RAG) is a powerful technique that combines information retrieval ...

# %% [markdown]
# <a id="token-splitter"></a>
# ## 6. TokenTextSplitter 🎯
#
# ### 🎓 INTERMEDIATE: Precise Token-Based Splitting
#
# **TokenTextSplitter** splits based on **tokens** (not characters).
# - More accurate for LLM context windows
# - Uses tiktoken (OpenAI's tokenizer)
# - Not the best choice, is mostly not preferred.
#
# You can change encoding type basis the LLM choice

# %%
from langchain_text_splitters import TokenTextSplitter

# Sample text
text = """The transformer architecture, introduced in the paper 'Attention Is All You Need', 
revolutionized natural language processing. It uses self-attention mechanisms to process 
sequences in parallel, making it much faster than recurrent neural networks."""

# Token-based splitter
token_splitter = TokenTextSplitter(
    chunk_size=50,  # 50 tokens (not characters!)
    chunk_overlap=10,
    encoding_name="cl100k_base"  # GPT-3.5/GPT-4 tokenizer
)

token_chunks = token_splitter.split_text(text)

print(f"Split into {len(token_chunks)} token-based chunks:\n")
for i, chunk in enumerate(token_chunks, 1):
    print(f"Chunk {i}: {chunk}\n")
# Out:
# Split into 1 token-based chunks:
#
# Chunk 1: The transformer architecture, introduced in the paper 'Attention Is All You Need',
# revolutionized natural language processing. It uses self-attention mechanisms to process
# sequences in parallel, making it much faster than recurrent neural networks.

# %% [markdown]
# <a id="optimization"></a>
# ## 7. Chunk Size & Overlap Optimization 📊
#
# ### 🔰 BEGINNER: Rules of Thumb
#
# #### Recommended Configurations
#
# | Content Type | Chunk Size | Overlap | Why |
# |-------------|-----------|---------|-----|
# | **General Text** | 1000 chars | 200 chars | Balanced precision & context |
# | **Technical Docs** | 500-800 | 100-150 | Precision for code/commands |
# | **Long Articles** | 1500-2000 | 300 | More context for narrative |
# | **Code** | 200-400 | 50-100 | Function/class level |
# | **FAQs** | 200-300 | 30-50 | Question-answer pairs |
#
# #### Overlap Guidelines
# - **10-15%**: Minimal overlap, saves storage
# - **20%**: Sweet spot (recommended)
# - **30%+**: Maximum context preservation

# %%
# Compare different chunk sizes
if Path(txt_path).exists():
    docs = TextLoader(txt_path).load()
    
    chunk_sizes = [500, 1000, 1500, 2000]
    
    print("📊 Chunk Size Comparison:\n")
    print(f"{'Size':<8} {'Chunks':<10} {'Avg Length':<12} {'Overlap %'}")
    print("-" * 50)
    
    for size in chunk_sizes:
        overlap = int(size * 0.2)  # 20% overlap
        
        splitter = RecursiveCharacterTextSplitter(
            chunk_size=size,
            chunk_overlap=overlap
        )
        
        chunks = splitter.split_documents(docs)
        avg_length = sum(len(c.page_content) for c in chunks) / len(chunks)
        overlap_pct = (overlap / size) * 100
        
        print(f"{size:<8} {len(chunks):<10} {avg_length:<12.0f} {overlap_pct:.0f}%")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 2
#       1 # Compare different chunk sizes
# ----> 2 if Path(txt_path).exists():
#       3     docs = TextLoader(txt_path).load()
#       4
#       5     chunk_sizes = [500, 1000, 1500, 2000]
#
# NameError: name 'txt_path' is not defined

# %% [markdown]
# <a id="comparison"></a>
# ## 8. Comparison & Best Practices 🌟
#
# ### Splitter Comparison
#
# | Splitter | Best For | Pros | Cons |
# |----------|----------|------|------|
# | **RecursiveCharacter** | General text, docs | Smart boundaries, flexible | Slower |
# | **Character** | Simple text | Fast, simple | Not intelligent |
# | **HTMLHeader** | Web content, docs | Preserves structure | HTML only |
# | **RecursiveJson** | JSON data | Preserves JSON structure | JSON only |
# | **Token** | Precise LLM usage | Accurate token count | Requires tokenizer |
#
# ### 🎓 Best Practices
#
# 1. **Start with RecursiveCharacterTextSplitter**
# 2. **Test different chunk sizes** with your data
# 3. **Use 20% overlap** as default
# 4. **Match splitter to content type** (HTML → HTMLHeaderTextSplitter)
# 5. **Monitor retrieval quality** and adjust
# 6. **Consider token-based splitting** for production

# %% [markdown]
# <a id="summary"></a>
# ## 9. Summary & Exercises 📝
#
# ### 🎉 What You Learned
#
# ✅ Text splitting is necessary because **LLMs have limited context windows**
#
# ✅ **RecursiveCharacterTextSplitter** is the recommended default
#
# ✅ **Chunk size** determines precision vs context trade-off
#
# ✅ **Overlap** (20%) preserves context across boundaries
#
# ✅ Different content types need different splitters
#
# ✅ **Best practice:** chunk_size=1000, chunk_overlap=200 for general text
#
# ### 💡 Practice Exercises
#
# #### 🔰 Beginner
# 1. Load a PDF and split it with chunk_size=500, overlap=100
# 2. Count total chunks created
# 3. Print first and last chunks
#
# #### 🎓 Intermediate
# 1. Compare chunk sizes (500, 1000, 2000) on the same document
# 2. Create a chart showing # of chunks vs chunk size
# 3. Test different overlap percentages (10%, 20%, 30%)
#
# ---
